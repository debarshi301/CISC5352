# %% [markdown]
# # Run an LSTM model for the two datasets and explain their performance (extra credits)

# %%
# LSTM for international airline passengers problem with regression framing
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# load the dataset
filename=['credit_risk_small_data_0.02.csv', 'credit_data_sim.csv']
data = read_csv(filename[0])
data
# Out:
#       Delinquency  Revolving Credit Percentage  Capital Reserves  Num Late 60  \
# 0               0                     0.390912                53            0
# 1               0                     0.037574                64            0
# 2               0                     0.002058                59            0
# 3               0                     1.023988                36            0
# 4               0                     0.966603                61            1
# ...           ...                          ...               ...          ...
# 2400            0                     0.058012                35            0
# 2401            0                     0.024283                91            2
# 2402            0                     0.271156                37            1
# 2403            0                     0.923689                35            0
# 2404            0                     0.291157                30            0
#
#       Debt Ratio  Monthly Income  Num Credit Lines  Num Late Past 90  \
# 0       0.241776           10000                 9                 0
# 1       0.323588           10500                11                 0
# 2       0.458093           16500                12                 0
# 3       0.203108            2766                 4                 0
# 4       0.350550            3000                 4                 0
# ...          ...             ...               ...               ...
# 2400    0.348095            4041                 8                 0
# 2401    0.118773            5800                 7                 0
# 2402    0.343996            9127                17                 0
# 2403    1.890141            2129                 9                 0
# 2404    0.088825            6585                 7                 0
#
#       Num Real Estate  Num Late 90  Num Employees
# 0                   1            0              2
# 1                   2            0              0
# 2                   2            0              2
# 3                   0            0              3
# 4                   1            0              0
# ...               ...          ...            ...
# 2400                2            0              3
# 2401                1            0              0
# 2402                1            0              1
# 2403                2            0              0
# 2404                0            0              0
#
# [2405 rows x 11 columns]

# %%
# normalize the dataset using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(data)
data = pd.DataFrame(data = X, columns = data.columns)
data
# Out:
#       Delinquency  Revolving Credit Percentage  Capital Reserves  Num Late 60  \
# 0             0.0                 7.537834e-05          0.432432     0.000000
# 1             0.0                 7.245282e-06          0.581081     0.000000
# 2             0.0                 3.968078e-07          0.513514     0.000000
# 3             0.0                 1.974524e-04          0.202703     0.000000
# 4             0.0                 1.863871e-04          0.540541     0.010204
# ...           ...                          ...               ...          ...
# 2400          0.0                 1.118625e-05          0.189189     0.000000
# 2401          0.0                 4.682493e-06          0.945946     0.020408
# 2402          0.0                 5.228615e-05          0.216216     0.010204
# 2403          0.0                 1.781120e-04          0.189189     0.000000
# 2404          0.0                 5.614293e-05          0.121622     0.000000
#
#       Debt Ratio  Monthly Income  Num Credit Lines  Num Late Past 90  \
# 0       0.000063        0.083333          0.214286               0.0
# 1       0.000085        0.087500          0.261905               0.0
# 2       0.000120        0.137500          0.285714               0.0
# 3       0.000053        0.023050          0.095238               0.0
# 4       0.000092        0.025000          0.095238               0.0
# ...          ...             ...               ...               ...
# 2400    0.000091        0.033675          0.190476               0.0
# 2401    0.000031        0.048333          0.166667               0.0
# 2402    0.000090        0.076058          0.404762               0.0
# 2403    0.000495        0.017742          0.214286               0.0
# 2404    0.000023        0.054875          0.166667               0.0
#
#       Num Real Estate  Num Late 90  Num Employees
# 0            0.052632          0.0       0.285714
# 1            0.105263          0.0       0.000000
# 2            0.105263          0.0       0.285714
# 3            0.000000          0.0       0.428571
# 4            0.052632          0.0       0.000000
# ...               ...          ...            ...
# 2400         0.105263          0.0       0.428571
# 2401         0.052632          0.0       0.000000
# 2402         0.052632          0.0       0.142857
# 2403         0.105263          0.0       0.000000
# 2404         0.000000          0.0       0.000000
#
# [2405 rows x 11 columns]

# %%
#Dealing with the imbalance issue with SMOTE
from imblearn.over_sampling import RandomOverSampler, SMOTE

delinquency = data['Delinquency']

sm = SMOTE(random_state = 33)
data, delinquency = sm.fit_resample(data, delinquency)
(n,p) = data.shape
print (n,p)
# Out:
# 4496 11

# %%
#Remove label from data
labels = data['Delinquency']
X = data.iloc[:,1:p]
X
# Out:
#       Revolving Credit Percentage  Capital Reserves  Num Late 60  Debt Ratio  \
# 0                    7.537834e-05          0.432432     0.000000    0.000063
# 1                    7.245282e-06          0.581081     0.000000    0.000085
# 2                    3.968078e-07          0.513514     0.000000    0.000120
# 3                    1.974524e-04          0.202703     0.000000    0.000053
# 4                    1.863871e-04          0.540541     0.010204    0.000092
# ...                           ...               ...          ...         ...
# 4491                 2.525121e-04          0.660205     0.020274    0.000286
# 4492                 1.925800e-04          0.188908     0.020337    0.000166
# 4493                 3.914688e-07          0.121787     0.000042    0.000036
# 4494                 6.448980e-05          0.268249     0.002893    0.000148
# 4495                 1.656464e-04          0.061249     0.000679    0.000084
#
#       Monthly Income  Num Credit Lines  Num Late Past 90  Num Real Estate  \
# 0           0.083333          0.214286          0.000000         0.052632
# 1           0.087500          0.261905          0.000000         0.105263
# 2           0.137500          0.285714          0.000000         0.105263
# 3           0.023050          0.095238          0.000000         0.000000
# 4           0.025000          0.095238          0.000000         0.052632
# ...              ...               ...               ...              ...
# 4491        0.049510          0.284774          0.000537         0.367035
# 4492        0.036018          0.118553          0.030400         0.052267
# 4493        0.034175          0.095530          0.030487         0.000430
# 4494        0.099166          0.407951          0.000000         0.128054
# 4495        0.032240          0.166667          0.000000         0.007005
#
#       Num Late 90  Num Employees
# 0        0.000000       0.285714
# 1        0.000000       0.000000
# 2        0.000000       0.285714
# 3        0.000000       0.428571
# 4        0.000000       0.000000
# ...           ...            ...
# 4491     0.010204       0.000000
# 4492     0.010133       0.142857
# 4493     0.010162       0.142857
# 4494     0.000000       0.000000
# 4495     0.000000       0.142857
#
# [4496 rows x 10 columns]

# %%
#80-20 split
train_data, test_data, train_data_delinquency, test_data_delinquency = train_test_split(X, labels,test_size=0.2, random_state=4,shuffle = True)#

print (train_data.shape, test_data.shape)
# Out:
# (3596, 10) (900, 10)

# %%
features_set = train_data
labels = train_data_delinquency

# %%
labels
# Out:
# 3822    1.0
# 2171    0.0
# 523     0.0
# 3692    1.0
# 2001    1.0
#        ...
# 3671    1.0
# 709     0.0
# 2487    1.0
# 174     0.0
# 1146    0.0
# Name: Delinquency, Length: 3596, dtype: float64

# %%
features_set
# Out:
#       Revolving Credit Percentage  Capital Reserves  Num Late 60  Debt Ratio  \
# 3822                     0.000086          0.337285     0.007757    0.000219
# 2171                     0.000021          0.202703     0.000000    0.000103
# 523                      0.000006          0.445946     0.000000    0.000011
# 3692                     0.000158          0.194501     0.016220    0.000048
# 2001                     0.000185          0.378378     0.000000    0.000171
# ...                           ...               ...          ...         ...
# 3671                     0.000114          0.338155     0.001438    0.000110
# 709                      0.000193          0.635135     0.000000    0.000010
# 2487                     0.000095          0.391022     0.009547    0.000108
# 174                      0.000078          0.243243     0.000000    0.000165
# 1146                     0.000012          0.513514     0.000000    0.000182
#
#       Monthly Income  Num Credit Lines  Num Late Past 90  Num Real Estate  \
# 3822        0.053596          0.357143          0.000000         0.132656
# 2171        0.040000          0.119048          0.000000         0.052632
# 523         0.087500          0.214286          0.000000         0.000000
# 3692        0.030678          0.085466          0.002005         0.020687
# 2001        0.067358          0.285714          0.000000         0.105263
# ...              ...               ...               ...              ...
# 3671        0.037418          0.143976          0.011163         0.105263
# 709         0.061850          0.095238          0.000000         0.000000
# 2487        0.033316          0.162070          0.000657         0.049244
# 174         0.028900          0.238095          0.000000         0.052632
# 1146        0.024300          0.428571          0.000000         0.105263
#
#       Num Late 90  Num Employees
# 3822     0.000000       0.000000
# 2171     0.000000       0.428571
# 523      0.000000       0.285714
# 3692     0.012209       0.571429
# 2001     0.000000       0.142857
# ...           ...            ...
# 3671     0.000240       0.142857
# 709      0.000000       0.000000
# 2487     0.000000       0.000000
# 174      0.000000       0.285714
# 1146     0.000000       0.000000
#
# [3596 rows x 10 columns]

# %%
features_set, labels = np.array(features_set), np.array(labels)

# %%
#Converting the data into the 3-D Format accepted by the LSTM
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
features_set.shape
# Out:
# (3596, 10, 1)

# %%
#Creating the model
model = Sequential()
#Creating LSTM and Dropout Layers
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

# %%
#model Compilation
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
#Training
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 6s 15ms/step - loss: 0.2947
# Epoch 2/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2565
# Epoch 3/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2546
# Epoch 4/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2472
# Epoch 5/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2455
# Epoch 6/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2474
# Epoch 7/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2440
# Epoch 8/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2406
# Epoch 9/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2365
# Epoch 10/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2363
# Epoch 11/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2387
# Epoch 12/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2385
# Epoch 13/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2352
# Epoch 14/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2378
# Epoch 15/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2374
# Epoch 16/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2368
# Epoch 17/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2367
# Epoch 18/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2352
# Epoch 19/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2293
# Epoch 20/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2322
# Epoch 21/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2319
# Epoch 22/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2457
# Epoch 23/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2395
# Epoch 24/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2340
# Epoch 25/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2349
# Epoch 26/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2285
# Epoch 27/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2294
# Epoch 28/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2288
# Epoch 29/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2299
# Epoch 30/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2282
# Epoch 31/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2338
# Epoch 32/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2241
# Epoch 33/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2281
# Epoch 34/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2289
# Epoch 35/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2265
# Epoch 36/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2287
# Epoch 37/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2276
# Epoch 38/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2274
# Epoch 39/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2223
# Epoch 40/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2295
# Epoch 41/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2266
# Epoch 42/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2249
# Epoch 43/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2234
# Epoch 44/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2268
# Epoch 45/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2192
# Epoch 46/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2190
# Epoch 47/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2254
# Epoch 48/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2247
# Epoch 49/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2246
# Epoch 50/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2252
# Epoch 51/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2217
# Epoch 52/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2218
# Epoch 53/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2203
# Epoch 54/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2231
# Epoch 55/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2201
# Epoch 56/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2193
# Epoch 57/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2173
# Epoch 58/100
# 113/113 [==============================] - 3s 23ms/step - loss: 0.2174
# Epoch 59/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2179
# Epoch 60/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2189
# Epoch 61/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2189
# Epoch 62/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2195
# Epoch 63/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2150
# Epoch 64/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2156
# Epoch 65/100
# 113/113 [==============================] - 3s 28ms/step - loss: 0.2144
# Epoch 66/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2156
# Epoch 67/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2158
# Epoch 68/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2152
# Epoch 69/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2161
# Epoch 70/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2108
# Epoch 71/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2133
# Epoch 72/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2130
# Epoch 73/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2159
# Epoch 74/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2195
# Epoch 75/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2193
# Epoch 76/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2108
# Epoch 77/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2151
# Epoch 78/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2137
# Epoch 79/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2136
# Epoch 80/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2155
# Epoch 81/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2079
# Epoch 82/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2116
# Epoch 83/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2144
# Epoch 84/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2113
# Epoch 85/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2068
# Epoch 86/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2090
# Epoch 87/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2088
# Epoch 88/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2053
# Epoch 89/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2113
# Epoch 90/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2077
# Epoch 91/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2079
# Epoch 92/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2097
# Epoch 93/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2113
# Epoch 94/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2090
# Epoch 95/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2046
# Epoch 96/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2054
# Epoch 97/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2054
# Epoch 98/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2093
# Epoch 99/100
# 113/113 [==============================] - 2s 14ms/step - loss: 0.2047
# Epoch 100/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.2066

# %%
#convert the test data into the LSTM format
test_data, test_data_delinquency = np.array(test_data), np.array(test_data_delinquency)

test_data = np.reshape(test_data, (test_data.shape[0], test_data.shape[1], 1))
test_data.shape
# Out:
# (900, 10, 1)

# %%
predictedDelinquency = model.predict(test_data)

predictedDelinquency.shape
# Out:
# (900, 1)

# %%
test_data_delinquency.shape
# Out:
# (900,)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(test_data_delinquency, predictedDelinquency)

# %%
r2
# Out:
# 0.1400230338147973

# %%
#Dataset 2

# %%
data = read_csv(filename[1])
data
# Out:
#       Working capital / Total Assets (WC_TA)  \
# 0                                      0.121
# 1                                      0.470
# 2                                      0.110
# 3                                      0.511
# 4                                      0.202
# ...                                      ...
# 1709                                     NaN
# 1710                                     NaN
# 1711                                     NaN
# 1712                                     NaN
# 1713                                     NaN
#
#       Retained Earnings / Total Assets (RE_TA)  \
# 0                                        0.413
# 1                                        0.752
# 2                                        0.337
# 3                                        0.869
# 4                                        0.460
# ...                                        ...
# 1709                                       NaN
# 1710                                       NaN
# 1711                                       NaN
# 1712                                       NaN
# 1713                                       NaN
#
#       Earnings Before Interests and Taxes / Total Assets (EBIT_TA)  \
# 0                                                 0.057
# 1                                                 0.070
# 2                                                 0.045
# 3                                                 0.106
# 4                                                 0.064
# ...                                                 ...
# 1709                                                NaN
# 1710                                                NaN
# 1711                                                NaN
# 1712                                                NaN
# 1713                                                NaN
#
#       Market Value of Equity / Book Value of Total Debt (MVE_BVTD)  \
# 0                                                 3.647
# 1                                                11.596
# 2                                                 3.835
# 3                                                 8.538
# 4                                                 3.685
# ...                                                 ...
# 1709                                                NaN
# 1710                                                NaN
# 1711                                                NaN
# 1712                                                NaN
# 1713                                                NaN
#
#       Sales / Total Assets (S_TA)  Industry sector labels from 1-12  \
# 0                           0.466                              12.0
# 1                           1.120                               8.0
# 2                           0.812                               4.0
# 3                           0.732                               2.0
# 4                           0.682                               4.0
# ...                           ...                               ...
# 1709                          NaN                               NaN
# 1710                          NaN                               NaN
# 1711                          NaN                               NaN
# 1712                          NaN                               NaN
# 1713                          NaN                               NaN
#
#       Credit status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1709            NaN
# 1710            NaN
# 1711            NaN
# 1712            NaN
# 1713            NaN
#
# [1714 rows x 7 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(data)
data = pd.DataFrame(data = X, columns = data.columns)
data
# Out:
#       Working capital / Total Assets (WC_TA)  \
# 0                                   0.765276
# 1                                   0.878112
# 2                                   0.761720
# 3                                   0.891368
# 4                                   0.791465
# ...                                      ...
# 1709                                     NaN
# 1710                                     NaN
# 1711                                     NaN
# 1712                                     NaN
# 1713                                     NaN
#
#       Retained Earnings / Total Assets (RE_TA)  \
# 0                                     0.731264
# 1                                     0.798299
# 2                                     0.716235
# 3                                     0.821436
# 4                                     0.740558
# ...                                        ...
# 1709                                       NaN
# 1710                                       NaN
# 1711                                       NaN
# 1712                                       NaN
# 1713                                       NaN
#
#       Earnings Before Interests and Taxes / Total Assets (EBIT_TA)  \
# 0                                              0.808989
# 1                                              0.825218
# 2                                              0.794007
# 3                                              0.870162
# 4                                              0.817728
# ...                                                 ...
# 1709                                                NaN
# 1710                                                NaN
# 1711                                                NaN
# 1712                                                NaN
# 1713                                                NaN
#
#       Market Value of Equity / Book Value of Total Debt (MVE_BVTD)  \
# 0                                              0.030447
# 1                                              0.097230
# 2                                              0.032026
# 3                                              0.071538
# 4                                              0.030766
# ...                                                 ...
# 1709                                                NaN
# 1710                                                NaN
# 1711                                                NaN
# 1712                                                NaN
# 1713                                                NaN
#
#       Sales / Total Assets (S_TA)  Industry sector labels from 1-12  \
# 0                        0.062000                          1.000000
# 1                        0.155429                          0.636364
# 2                        0.111429                          0.272727
# 3                        0.100000                          0.090909
# 4                        0.092857                          0.272727
# ...                           ...                               ...
# 1709                          NaN                               NaN
# 1710                          NaN                               NaN
# 1711                          NaN                               NaN
# 1712                          NaN                               NaN
# 1713                          NaN                               NaN
#
#       Credit status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1709            NaN
# 1710            NaN
# 1711            NaN
# 1712            NaN
# 1713            NaN
#
# [1714 rows x 7 columns]

# %%
data = data.dropna() #dropping NaN's
data
# Out:
#       Working capital / Total Assets (WC_TA)  \
# 0                                   0.765276
# 1                                   0.878112
# 2                                   0.761720
# 3                                   0.891368
# 4                                   0.791465
# ...                                      ...
# 1665                                0.706111
# 1666                                0.446169
# 1667                                0.678629
# 1668                                0.656644
# 1669                                0.673780
#
#       Retained Earnings / Total Assets (RE_TA)  \
# 0                                     0.731264
# 1                                     0.798299
# 2                                     0.716235
# 3                                     0.821436
# 4                                     0.740558
# ...                                        ...
# 1665                                  0.509788
# 1666                                  0.510777
# 1667                                  0.628436
# 1668                                  0.453233
# 1669                                  0.495946
#
#       Earnings Before Interests and Taxes / Total Assets (EBIT_TA)  \
# 0                                              0.808989
# 1                                              0.825218
# 2                                              0.794007
# 3                                              0.870162
# 4                                              0.817728
# ...                                                 ...
# 1665                                           0.780275
# 1666                                           0.600499
# 1667                                           0.744070
# 1668                                           0.731586
# 1669                                           0.727840
#
#       Market Value of Equity / Book Value of Total Debt (MVE_BVTD)  \
# 0                                              0.030447
# 1                                              0.097230
# 2                                              0.032026
# 3                                              0.071538
# 4                                              0.030766
# ...                                                 ...
# 1665                                           0.000706
# 1666                                           0.009124
# 1667                                           0.003159
# 1668                                           0.001319
# 1669                                           0.002865
#
#       Sales / Total Assets (S_TA)  Industry sector labels from 1-12  \
# 0                        0.062000                          1.000000
# 1                        0.155429                          0.636364
# 2                        0.111429                          0.272727
# 3                        0.100000                          0.090909
# 4                        0.092857                          0.272727
# ...                           ...                               ...
# 1665                     0.023571                          0.909091
# 1666                     0.046714                          1.000000
# 1667                     0.019714                          0.727273
# 1668                     0.006143                          0.454545
# 1669                     0.009714                          0.545455
#
#       Credit status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1665            0.0
# 1666            0.0
# 1667            0.0
# 1668            0.0
# 1669            0.0
#
# [1670 rows x 7 columns]

# %%
#since the data is imbalanced
#using SMOTE to fix the problem
creditstatus = data['Credit status']
sm = SMOTE(random_state = 33)
data, creditstatus = sm.fit_resample(data, creditstatus)

print (data.shape, creditstatus.shape)
# Out:
# (3080, 7) (3080,)

# %%
#Remove label from data
(n,p) = data.shape
X = data.iloc[:, :p-1]
X.shape
# Out:
# (3080, 6)

# %%
#Splitting the data- 80-20 split
train_data, test_data, train_data_creditstatus, test_data_creditstatus = train_test_split(X, creditstatus,test_size=0.2, random_state=42)

print (train_data.shape)
# Out:
# (2464, 6)

# %%
features_set = train_data
labels = train_data_creditstatus
features_set, labels = np.array(features_set), np.array(labels)

features_set
# Out:
# array([[6.97816871e-01, 5.16685799e-01, 7.46101360e-01, 5.60042142e-04,
#         8.46711602e-03, 8.18181818e-01],
#        [7.02694511e-01, 4.89577252e-01, 7.69053093e-01, 6.44720391e-04,
#         3.62587067e-03, 2.72727273e-01],
#        [6.83810853e-01, 5.34633805e-01, 7.43925100e-01, 1.61915625e-03,
#         1.17908068e-02, 7.27272727e-01],
#        ...,
#        [8.46750727e-01, 7.39766660e-01, 8.42696629e-01, 1.33751166e-02,
#         3.10000000e-02, 9.09090909e-02],
#        [8.07953443e-01, 7.37789203e-01, 8.20224719e-01, 1.18880590e-02,
#         3.88571429e-02, 9.09090909e-02],
#        [8.23472357e-01, 7.38184694e-01, 8.21473159e-01, 2.44902417e-02,
#         5.12857143e-02, 2.72727273e-01]])

# %%
#Converting the data into the 3-D Format accepted by the LSTM
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
features_set.shape
# Out:
# (2464, 6, 1)

# %%
#Creating the model
model = Sequential()
#Creating LSTM and Dropout Layers
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

# %%
#model Compilation
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
#Training
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 5s 8ms/step - loss: 0.3025
# Epoch 2/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.1125
# Epoch 3/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.1032A: 0s - loss:
# Epoch 4/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0757
# Epoch 5/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0411
# Epoch 6/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0227
# Epoch 7/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0165
# Epoch 8/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0241
# Epoch 9/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0148
# Epoch 10/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0179
# Epoch 11/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0140
# Epoch 12/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0150
# Epoch 13/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 14/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 15/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 16/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 17/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0163
# Epoch 18/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0156
# Epoch 19/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 20/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0188
# Epoch 21/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 22/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0256
# Epoch 23/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 24/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0162
# Epoch 25/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0152
# Epoch 26/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0128
# Epoch 27/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0191
# Epoch 28/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0105
# Epoch 29/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0136
# Epoch 30/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0084
# Epoch 31/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 32/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 33/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 34/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0167
# Epoch 35/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 36/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0076
# Epoch 37/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0099
# Epoch 38/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 39/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0100
# Epoch 40/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0141
# Epoch 41/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0088
# Epoch 42/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0105
# Epoch 43/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0126
# Epoch 44/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 45/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 46/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0131
# Epoch 47/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0127
# Epoch 48/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0171
# Epoch 49/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0117
# Epoch 50/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0095
# Epoch 51/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0105
# Epoch 52/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0087
# Epoch 53/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0074
# Epoch 54/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0119
# Epoch 55/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0079
# Epoch 56/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0069
# Epoch 57/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0062
# Epoch 58/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0079
# Epoch 59/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0079
# Epoch 60/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 61/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 62/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0095
# Epoch 63/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0109
# Epoch 64/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0092
# Epoch 65/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 66/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0208
# Epoch 67/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 68/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 69/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0099
# Epoch 70/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0123
# Epoch 71/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0080
# Epoch 72/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0077
# Epoch 73/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0091
# Epoch 74/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0061
# Epoch 75/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0149
# Epoch 76/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0081
# Epoch 77/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0134
# Epoch 78/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0105
# Epoch 79/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0075
# Epoch 80/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 81/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0096
# Epoch 82/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0085
# Epoch 83/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 84/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0080
# Epoch 85/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 86/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0086
# Epoch 87/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0089
# Epoch 88/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 89/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 90/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0089
# Epoch 91/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 92/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0106
# Epoch 93/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0112
# Epoch 94/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0060
# Epoch 95/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0083
# Epoch 96/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0094
# Epoch 97/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0084
# Epoch 98/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0107
# Epoch 99/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0084
# Epoch 100/100
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0074

# %%
#convert the test data into the LSTM format
test_data, test_data_creditstatus = np.array(test_data), np.array(test_data_creditstatus)

test_data = np.reshape(test_data, (test_data.shape[0], test_data.shape[1], 1))
test_data.shape
# Out:
# (616, 6, 1)

# %%
predictedCreditStatus = model.predict(test_data)

predictedCreditStatus.shape
# Out:
# (616, 1)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(test_data_creditstatus, predictedCreditStatus)

# %%
r2
# Out:
# 0.9685213162444034
